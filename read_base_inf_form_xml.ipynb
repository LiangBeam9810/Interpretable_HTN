# %%
import xml.dom.minidom as dm
import pandas as pd
import numpy as np
import os

# %%
df_data = pd.DataFrame()
signals_path = ["./HTN", "./NHTN"]
samp_num = 0

# %%
df_data = pd.DataFrame()
num = 0
for path_ch in signals_path:
    seq_files = os.listdir(path_ch)#返回指定的文件夹包含的文件或文件夹的名字的列表
    seq_files.sort()              #排序
    if(path_ch == signals_path[0]):
        state = "HTN"
    else:
        state = "NHTN"
    for fil_ch in seq_files:
        patienNumber = num
        doc = dm.parse(os.path.join(path_ch,fil_ch))
        name =  (doc.getElementsByTagName('name'))[1].childNodes[0].data
        date = (doc.getElementsByTagName('center'))[0].getAttribute("value")
        gender =  (doc.getElementsByTagName('administrativeGenderCode'))[0].getAttribute("code")
        gread = (doc.getElementsByTagName('gread'))[0].childNodes[0].data
        digcode = (doc.getElementsByTagName('digcode'))[0].childNodes[0].data
        birthTime = (doc.getElementsByTagName('birthTime'))[0].getAttribute("value")
        data = {}
        data['patienNumber'] = patienNumber,
        data['name'] = name,
        data['state']= state,
        data['date']= date,
        data['birthTime'] = birthTime,
        data['gender'] = gender,
        data['gread'] = gread,
        data['digcode'] = digcode
        df_data = df_data.append(data,ignore_index=True)
        num = num + 1

# %%
df_data
# Out:
#      patienNumber    name    state               date       birthTime gender  \
# 0            (0,)   (王滨,)   (HTN,)  (20151230151911,)             (,)   (M,)
# 1            (1,)  (张水海,)   (HTN,)  (20170210113704,)  (19350711ttt,)   (M,)
# 2            (2,)  (林加顺,)   (HTN,)  (20180611210459,)  (19800717ttt,)   (M,)
# 3            (3,)  (方建鑫,)   (HTN,)  (20180612121237,)  (19870314ttt,)   (M,)
# 4            (4,)   (郑劼,)   (HTN,)  (20180612182013,)  (19911212ttt,)   (F,)
# ...           ...     ...      ...                ...             ...    ...
# 1678      (1678,)  (陈天启,)  (NHTN,)  (20170622083342,)  (19491202ttt,)   (M,)
# 1679      (1679,)  (陈养妹,)  (NHTN,)  (20170622092814,)  (19251110ttt,)   (F,)
# 1680      (1680,)  (骆焕斌,)  (NHTN,)  (20170622095843,)  (19580816ttt,)   (M,)
# 1681      (1681,)  (林细珠,)  (NHTN,)  (20170622161815,)  (19440408ttt,)   (F,)
# 1682      (1682,)  (吴端恭,)  (NHTN,)  (20170622174039,)  (19460417ttt,)   (M,)
#
#                                    gread  \
# 0                        (窦性心律 \n正常心电图,)
# 1                        (窦性心律\nST-T改变,)
# 2                              (窦性心动过缓,)
# 3                          (窦性心律\nT波改变,)
# 4                      ( 窦性心律 \n 正常心电图,)
# ...                                  ...
# 1678                   ( 窦性心律 \n 正常心电图,)
# 1679                      (窦性心律\n逆钟向转位,)
# 1680                       (窦性心律\nT波改变,)
# 1681  (窦性心动过缓\n房性早搏\n建议动态心电图（12导）进一步检查,)
# 1682                     (窦性心律\nT波轻度改变,)
#
#                                                 digcode
# 0                PⅠ、Ⅱ直立，PavR倒置，P波、P－R间期、QRS波、ST-T无异常改变。
# 1     PⅠ、Ⅱ直立，PavR倒置。\nST：V5、V6 水平型压低0.05-0.075  mv\n...
# 2     PⅠ、Ⅱ直立，PavR倒置，P波、P－R间期、QRS波、ST-T无异常改变，心率低于正常范围...
# 3                PⅠ、Ⅱ直立，PavR倒置。\nT：Ⅰ、aVL、V4、V5、V6 低平、双向
# 4                PⅠ、Ⅱ直立，PavR倒置，P波、P－R间期、QRS波、ST-T无异常改变。
# ...                                                 ...
# 1678             PⅠ、Ⅱ直立，PavR倒置，P波、P－R间期、QRS波、ST-T无异常改变。
# 1679                    PⅠ、Ⅱ直立，PavR倒置。\nV2-V6呈Rs，R/S>1。
# 1680                       PⅠ、Ⅱ直立，PavR倒置。\nT：Ⅱ、Ⅲ、aVF 低平
# 1681  PⅠ、Ⅱ直立，PavR倒置，心率低于正常范围,HR<60（>6岁）次/分。\n各导联见提前P...
# 1682                         PⅠ、Ⅱ直立，PavR倒置。\nT：Ⅰ、aVL 低平
#
# [1683 rows x 8 columns]

# %%
df_data.to_csv(path_or_buf="./base_inf.xlsx",sep=",",encoding="utf-8_sig")
